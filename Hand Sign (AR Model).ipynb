# %%
import os
import cv2
##import pafy  (only use if need)
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

seed = 9919
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

# %%
all_classes_names = os.listdir('AISG2')
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (5, 5))

# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 5)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'AISG2/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'AISG2/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    video_reader.release()

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 60,60

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 24

# Specify the directory containing the UCF50 dataset. 
DATASET_DIR = "AISG2"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = all_classes_names

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video. 
        success, frame = video_reader.read() 

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the videos having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    
    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()

# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed)
# Out:
# Extracting Data of Class: BukitGombak
# Extracting Data of Class: CityHall
# Extracting Data of Class: Commonwealth
# Extracting Data of Class: Kallang
# Extracting Data of Class: OutramPark

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
    
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.2)))
                                      
    model.add(TimeDistributed(Flatten()))
                                      
    model.add(LSTM(8))
                                      
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()
    
    # Return the constructed LRCN model.
    return model

# %%
# Construct the required LRCN model.
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 24, 60, 60, 16)   448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 24, 15, 15, 16)   0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 24, 15, 15, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 24, 15, 15, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 24, 7, 7, 32)     0
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 24, 7, 7, 32)     0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 24, 7, 7, 32)     9248
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 24, 3, 3, 32)     0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 24, 3, 3, 32)     0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 24, 288)          0
#  tributed)
#
#  lstm (LSTM)                 (None, 8)                 9504
#
#  dense (Dense)               (None, 5)                 45
#
# =================================================================
# Total params: 23,885
# Trainable params: 23,885
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 100, batch_size = 4,
                                             shuffle = True, validation_split = 0.3)#, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/100
# 61/61 [==============================] - 13s 28ms/step - loss: 1.6332 - accuracy: 0.2181 - val_loss: 1.6151 - val_accuracy: 0.1905
# Epoch 2/100
# 61/61 [==============================] - 1s 14ms/step - loss: 1.6138 - accuracy: 0.2058 - val_loss: 1.6156 - val_accuracy: 0.1810
# Epoch 3/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.6148 - accuracy: 0.2058 - val_loss: 1.6149 - val_accuracy: 0.1810
# Epoch 4/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.6058 - accuracy: 0.2305 - val_loss: 1.6124 - val_accuracy: 0.2000
# Epoch 5/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.6024 - accuracy: 0.2469 - val_loss: 1.6109 - val_accuracy: 0.2095
# Epoch 6/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.5990 - accuracy: 0.2346 - val_loss: 1.6055 - val_accuracy: 0.2000
# Epoch 7/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.5928 - accuracy: 0.2798 - val_loss: 1.6022 - val_accuracy: 0.2095
# Epoch 8/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.5788 - accuracy: 0.2428 - val_loss: 1.6330 - val_accuracy: 0.2000
# Epoch 9/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.5856 - accuracy: 0.2428 - val_loss: 1.6090 - val_accuracy: 0.2095
# Epoch 10/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.5476 - accuracy: 0.3004 - val_loss: 1.6197 - val_accuracy: 0.2190
# Epoch 11/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.5108 - accuracy: 0.3416 - val_loss: 1.6736 - val_accuracy: 0.2095
# Epoch 12/100
# 61/61 [==============================] - 1s 14ms/step - loss: 1.4828 - accuracy: 0.3498 - val_loss: 1.6286 - val_accuracy: 0.1619
# Epoch 13/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.4047 - accuracy: 0.3868 - val_loss: 1.6542 - val_accuracy: 0.2095
# Epoch 14/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.4222 - accuracy: 0.3786 - val_loss: 1.6629 - val_accuracy: 0.2571
# Epoch 15/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.3227 - accuracy: 0.4609 - val_loss: 1.6540 - val_accuracy: 0.2476
# Epoch 16/100
# 61/61 [==============================] - 1s 15ms/step - loss: 1.2468 - accuracy: 0.4856 - val_loss: 1.7485 - val_accuracy: 0.2381
# Epoch 17/100
# 61/61 [==============================] - 1s 14ms/step - loss: 1.1326 - accuracy: 0.5597 - val_loss: 1.8271 - val_accuracy: 0.2571
# Epoch 18/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.0777 - accuracy: 0.5597 - val_loss: 1.7757 - val_accuracy: 0.2857
# Epoch 19/100
# 61/61 [==============================] - 1s 13ms/step - loss: 1.0243 - accuracy: 0.6255 - val_loss: 1.8206 - val_accuracy: 0.2952
# Epoch 20/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.8644 - accuracy: 0.6872 - val_loss: 2.0834 - val_accuracy: 0.2571
# Epoch 21/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.8803 - accuracy: 0.6831 - val_loss: 1.8538 - val_accuracy: 0.2667
# Epoch 22/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7351 - accuracy: 0.7490 - val_loss: 2.0090 - val_accuracy: 0.2952
# Epoch 23/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6935 - accuracy: 0.7613 - val_loss: 1.9514 - val_accuracy: 0.2857
# Epoch 24/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6445 - accuracy: 0.7942 - val_loss: 2.0198 - val_accuracy: 0.3333
# Epoch 25/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5383 - accuracy: 0.8477 - val_loss: 2.2031 - val_accuracy: 0.2857
# Epoch 26/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5678 - accuracy: 0.8395 - val_loss: 2.0961 - val_accuracy: 0.3143
# Epoch 27/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5567 - accuracy: 0.8148 - val_loss: 2.1936 - val_accuracy: 0.3143
# Epoch 28/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4626 - accuracy: 0.8724 - val_loss: 2.3590 - val_accuracy: 0.2476
# Epoch 29/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4717 - accuracy: 0.8354 - val_loss: 2.2423 - val_accuracy: 0.2857
# Epoch 30/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3965 - accuracy: 0.9095 - val_loss: 2.3414 - val_accuracy: 0.2571
# Epoch 31/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4033 - accuracy: 0.8724 - val_loss: 2.2685 - val_accuracy: 0.3048
# Epoch 32/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3219 - accuracy: 0.9218 - val_loss: 2.4186 - val_accuracy: 0.3143
# Epoch 33/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3639 - accuracy: 0.8930 - val_loss: 2.2306 - val_accuracy: 0.3048
# Epoch 34/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3419 - accuracy: 0.9095 - val_loss: 2.3154 - val_accuracy: 0.2952
# Epoch 35/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3265 - accuracy: 0.9095 - val_loss: 2.4264 - val_accuracy: 0.2381
# Epoch 36/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2996 - accuracy: 0.9218 - val_loss: 2.3443 - val_accuracy: 0.3429
# Epoch 37/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3618 - accuracy: 0.8889 - val_loss: 2.4872 - val_accuracy: 0.2857
# Epoch 38/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3945 - accuracy: 0.8971 - val_loss: 2.4232 - val_accuracy: 0.3238
# Epoch 39/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2597 - accuracy: 0.9300 - val_loss: 2.6492 - val_accuracy: 0.2762
# Epoch 40/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2249 - accuracy: 0.9506 - val_loss: 2.5068 - val_accuracy: 0.3048
# Epoch 41/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2332 - accuracy: 0.9506 - val_loss: 2.5786 - val_accuracy: 0.2667
# Epoch 42/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2653 - accuracy: 0.9259 - val_loss: 2.7405 - val_accuracy: 0.2952
# Epoch 43/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2758 - accuracy: 0.9095 - val_loss: 2.6017 - val_accuracy: 0.2952
# Epoch 44/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2354 - accuracy: 0.9383 - val_loss: 2.6497 - val_accuracy: 0.2667
# Epoch 45/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2035 - accuracy: 0.9300 - val_loss: 2.5341 - val_accuracy: 0.2857
# Epoch 46/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1738 - accuracy: 0.9630 - val_loss: 2.6197 - val_accuracy: 0.3238
# Epoch 47/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1659 - accuracy: 0.9671 - val_loss: 2.7015 - val_accuracy: 0.2667
# Epoch 48/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1651 - accuracy: 0.9712 - val_loss: 2.7948 - val_accuracy: 0.2952
# Epoch 49/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1467 - accuracy: 0.9588 - val_loss: 2.6346 - val_accuracy: 0.3619
# Epoch 50/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1298 - accuracy: 0.9794 - val_loss: 2.7649 - val_accuracy: 0.2952
# Epoch 51/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1331 - accuracy: 0.9753 - val_loss: 2.8043 - val_accuracy: 0.2667
# Epoch 52/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1148 - accuracy: 0.9835 - val_loss: 2.7567 - val_accuracy: 0.3238
# Epoch 53/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0857 - accuracy: 0.9918 - val_loss: 2.8302 - val_accuracy: 0.3238
# Epoch 54/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0996 - accuracy: 0.9794 - val_loss: 2.9086 - val_accuracy: 0.3429
# Epoch 55/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1131 - accuracy: 0.9753 - val_loss: 2.8366 - val_accuracy: 0.3238
# Epoch 56/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1090 - accuracy: 0.9877 - val_loss: 2.9344 - val_accuracy: 0.3143
# Epoch 57/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1081 - accuracy: 0.9753 - val_loss: 2.8577 - val_accuracy: 0.3238
# Epoch 58/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1199 - accuracy: 0.9712 - val_loss: 2.9583 - val_accuracy: 0.3143
# Epoch 59/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1405 - accuracy: 0.9671 - val_loss: 2.9349 - val_accuracy: 0.3048
# Epoch 60/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1495 - accuracy: 0.9547 - val_loss: 3.1206 - val_accuracy: 0.2571
# Epoch 61/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1544 - accuracy: 0.9630 - val_loss: 2.8857 - val_accuracy: 0.2952
# Epoch 62/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1206 - accuracy: 0.9630 - val_loss: 3.2032 - val_accuracy: 0.2952
# Epoch 63/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1696 - accuracy: 0.9588 - val_loss: 3.1405 - val_accuracy: 0.2190
# Epoch 64/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2026 - accuracy: 0.9259 - val_loss: 3.2423 - val_accuracy: 0.3048
# Epoch 65/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1261 - accuracy: 0.9753 - val_loss: 3.0149 - val_accuracy: 0.3238
# Epoch 66/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2182 - accuracy: 0.9218 - val_loss: 2.9064 - val_accuracy: 0.3143
# Epoch 67/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0731 - accuracy: 0.9835 - val_loss: 3.0027 - val_accuracy: 0.3238
# Epoch 68/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0677 - accuracy: 0.9918 - val_loss: 3.1399 - val_accuracy: 0.3333
# Epoch 69/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0641 - accuracy: 0.9835 - val_loss: 3.3409 - val_accuracy: 0.2762
# Epoch 70/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0679 - accuracy: 0.9918 - val_loss: 3.2736 - val_accuracy: 0.2667
# Epoch 71/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0662 - accuracy: 0.9877 - val_loss: 3.1776 - val_accuracy: 0.2952
# Epoch 72/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0573 - accuracy: 0.9918 - val_loss: 3.3654 - val_accuracy: 0.3143
# Epoch 73/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0498 - accuracy: 0.9918 - val_loss: 3.3985 - val_accuracy: 0.2952
# Epoch 74/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0482 - accuracy: 0.9918 - val_loss: 3.2657 - val_accuracy: 0.3143
# Epoch 75/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 3.4270 - val_accuracy: 0.3143
# Epoch 76/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2381 - accuracy: 0.9300 - val_loss: 3.4915 - val_accuracy: 0.2286
# Epoch 77/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1828 - accuracy: 0.9547 - val_loss: 3.5828 - val_accuracy: 0.2286
# Epoch 78/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2714 - accuracy: 0.9177 - val_loss: 2.9305 - val_accuracy: 0.3333
# Epoch 79/100
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1446 - accuracy: 0.9547 - val_loss: 3.0131 - val_accuracy: 0.3143
# Epoch 80/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0902 - accuracy: 0.9712 - val_loss: 3.1261 - val_accuracy: 0.3048
# Epoch 81/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0719 - accuracy: 0.9753 - val_loss: 3.1224 - val_accuracy: 0.3238
# Epoch 82/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0614 - accuracy: 0.9877 - val_loss: 3.1996 - val_accuracy: 0.3048
# Epoch 83/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0473 - accuracy: 0.9918 - val_loss: 3.2681 - val_accuracy: 0.3238
# Epoch 84/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0504 - accuracy: 0.9918 - val_loss: 3.4633 - val_accuracy: 0.2952
# Epoch 85/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0534 - accuracy: 0.9918 - val_loss: 3.2811 - val_accuracy: 0.3143
# Epoch 86/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0749 - accuracy: 0.9794 - val_loss: 3.2742 - val_accuracy: 0.3333
# Epoch 87/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1382 - accuracy: 0.9588 - val_loss: 3.3567 - val_accuracy: 0.2857
# Epoch 88/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0882 - accuracy: 0.9753 - val_loss: 3.2654 - val_accuracy: 0.3524
# Epoch 89/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0446 - accuracy: 0.9877 - val_loss: 3.3148 - val_accuracy: 0.3143
# Epoch 90/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0360 - accuracy: 0.9918 - val_loss: 3.3972 - val_accuracy: 0.3619
# Epoch 91/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0280 - accuracy: 0.9959 - val_loss: 3.3968 - val_accuracy: 0.3714
# Epoch 92/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 3.3881 - val_accuracy: 0.3905
# Epoch 93/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0484 - accuracy: 0.9918 - val_loss: 3.4219 - val_accuracy: 0.3238
# Epoch 94/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 3.3887 - val_accuracy: 0.3619
# Epoch 95/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0240 - accuracy: 0.9959 - val_loss: 3.5472 - val_accuracy: 0.3238
# Epoch 96/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0405 - accuracy: 0.9959 - val_loss: 3.5407 - val_accuracy: 0.3333
# Epoch 97/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0479 - accuracy: 0.9877 - val_loss: 3.5201 - val_accuracy: 0.3048
# Epoch 98/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1394 - accuracy: 0.9588 - val_loss: 3.6636 - val_accuracy: 0.2667
# Epoch 99/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2263 - accuracy: 0.9300 - val_loss: 3.3364 - val_accuracy: 0.3048
# Epoch 100/100
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1524 - accuracy: 0.9465 - val_loss: 3.5463 - val_accuracy: 0.2667

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
# Visualize the training and validation loss metrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 4/4 [==============================] - 0s 47ms/step - loss: 2.7886 - accuracy: 0.4017

# %%
# Plot the structure of the contructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save the Model.
LRCN_model.save(model_file_name)

# %%
print(features.shape)
# Out:
# (465, 24, 60, 60, 3)
